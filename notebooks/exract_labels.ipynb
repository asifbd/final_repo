# %% [markdown]
# # Overview
#
# This notebook is used to analyze available attributes and their values, and potentially map the attributes with wider range of values to a smaller set of generic values so that there is enough sample available for each class.

# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
import os
import mysql.connector

conn = mysql.connector.connect(host=os.getenv("MYSQL_HOST") , user=os.getenv("MYSQL_USER"), password=os.getenv("MYSQL_PASSWORD"), database=os.getenv("MYSQL_DB"), auth_plugin='mysql_native_password')

cursor = conn.cursor()

# %%
import pandas as pd

def get_annotable_items():
	query = """ 
			SELECT p.id, p.product_name, p.category, p.sub_category, r.details 
			FROM products p 
			JOIN raw_details r ON p.id = r.product_id
			JOIN annotation_status a on p.id=a.product_id
			WHERE a.flagged = 0;
			"""
	
	cursor.execute(query)
	
	rows = cursor.fetchall()
	columns = [i[0] for i in cursor.description]

	df = pd.DataFrame(rows, columns=columns)
	df_normalized = pd.json_normalize(df['details'].apply(eval))
	df = pd.concat([df, df_normalized], axis=1)

	df = df[[
		'id',
		'category',
		'sub_category',
		'title',
		'description',
		'images',
		'specs.Colour',
		'specs.Fabric',
		'specs.Value Addition',
		'specs.Cut /Fit',
		'specs.Collar/Neck',
		'specs.Sleeve',
		'specs.Bottom Colour',
		'specs.Bottom Fabric',
		'specs.Dupatta Colour',
		'specs.Dupatta Fabric'
	]]

	return df

# %%
df = get_annotable_items()

df.sample(2)
# Out:
#         id        category sub_category  \
# 4293  7007         Panjabi          N/A
# 2602  2604  Shalwar Kameez       Casual
#
#                                                   title  \
# 4293                      Beige Textured Cotton Panjabi
# 2602  Peach Printed and Embroidered Cotton Shalwar K...
#
#                                             description  \
# 4293  Beige textured cotton panjabi. Whether it's a ...
# 2602  Peach printed cotton kameez with shades of blu...
#
#                                                  images specs.Colour  \
# 4293  [https://www.aarong.com/media/catalog/product/...        Brown
# 2602  [https://www.aarong.com/media/catalog/product/...       Orange
#
#      specs.Fabric specs.Value Addition specs.Cut /Fit specs.Collar/Neck  \
# 4293       Cotton          Block Print         A-Line       Band Collar
# 2602       Cotton      Hand Embroidery         A-Line            V Neck
#
#           specs.Sleeve specs.Bottom Colour specs.Bottom Fabric  \
# 4293  3-Quarter Sleeve                 NaN                 NaN
# 2602  3-Quarter Sleeve                 NaN                 NaN
#
#      specs.Dupatta Colour specs.Dupatta Fabric
# 4293                  NaN                  NaN
# 2602                  NaN                  NaN

# %%
df['specs.Colour'].value_counts()
# Out:
# specs.Colour
# Green      821
# Brown      569
# Blue       559
# Purple     458
# Orange     440
# White      422
# Pink       366
# Yellow     301
# Red        283
# Grey       257
# Black      248
# Cyan       155
# Magenta    153
# Olive      129
# Maroon     100
# Golden      25
# Name: count, dtype: int64

# %%
for index, row in df.iterrows():
	print(row['specs.Value Addition'])
	break
# Out:
# Hand Embroidery

# %%
fabric_mapping = {
		"Cotton": "Cotton",
		"Handloom Cotton": "Cotton",
		"Vortex-Cotton": "Cotton",
		"Vortex Cotton": "Cotton",
		"Ramie Cotton": "Cotton",
		"Mixed Cotton": "Cotton Blend",
		"Cottray (Cotton & Rayon)": "Cotton Blend",
		"Single Jersey Knit Cotton": "Cotton Knit",
		"Muslin": "Muslin",
		"Endi Muslin": "Muslin",
		"Mixed Muslin (Muslin & Endi)": "Muslin Blend",
		"Blended Muslin (Muslin & Silk)": "Muslin Blend",
		"Mixed Muslin": "Muslin Blend",
		"Silk": "Silk",
		"Soft Silk": "Silk",
		"Dupion Silk": "Silk",
		"Joysree Silk": "Silk",
		"Katan": "Silk",
		"Endi Silk": "Silk",
		"Endi Silk-Muslin": "Silk Blend",
		"Half Silk (Silk & Cotton)": "Silk Blend",
		"Mixed Silk (Silk & Cotton)": "Silk Blend",
		"Jamdani Half Silk (Silk & Cotton)": "Silk Blend",
		"SICO (Silk & Cotton)": "Silk Blend",
		"Mixed Silk": "Silk Blend",
		"Viscose": "Viscose",
		"Jacquard Viscose": "Viscose",
		"Handloom Viscose": "Viscose",
		"Mixed Viscose": "Viscose Blend",
		"Viscott (Viscose & Cotton)": "Viscose Blend",
		"Linen": "Linen",
		"Satin": "Satin",
		"Satin Cotton": "Satin Blend",
		"Georgette": "Georgette",
		"Poplin": "Poplin",
		"Denim": "Denim",
		"Mixed Vortex": "Blended Fabric",
		"Addi Cotton": "Blended Fabric",
		"Cashmilon": "Synthetic",
		"Wool": "Wool",
	}

if 'Wool' in fabric_mapping:
	print("Wool is in the mapping")
# Out:
# Wool is in the mapping

# %%
df['specs.Fabric'].value_counts()
# Out:
# specs.Fabric
# Cotton                               1999
# Viscott (Viscose & Cotton)            720
# Silk                                  705
# Viscose                               618
# Muslin                                395
# Voile                                 227
# Half Silk (Silk & Cotton)             129
# Linen                                  78
# Handloom Viscose                       73
# Endi Silk                              66
# Mixed Cotton                           39
# Soft Silk                              34
# Handloom Cotton                        29
# Jamdani Half Silk (Silk & Cotton)      27
# Mixed Viscose                          25
# Mixed Silk (Silk & Cotton)             20
# Cashmilon                              14
# Poplin                                 11
# Addi Cotton                            10
# Jacquard Viscose                        8
# Mixed Muslin (Muslin & Endi)            7
# Ramie Cotton                            7
# Wool                                    7
# Blended Muslin (Muslin & Silk)          5
# Katan                                   4
# Cottray (Cotton & Rayon)                4
# Vortex-Cotton                           3
# Mixed Silk                              3
# Joysree Silk                            3
# Endi Muslin                             2
# Dupion Silk                             2
# Mixed Vortex                            1
# Single Jersey Knit Cotton               1
# Georgette                               1
# Endi Silk-Muslin                        1
# Satin Cotton                            1
# SICO (Silk & Cotton)                    1
# Satin                                   1
# Mixed Muslin                            1
# Vortex Cotton                           1
# Denim                                   1
# Name: count, dtype: int64

# %%
df['specs.Value Addition'].value_counts()
# Out:
# specs.Value Addition
# Hand Embroidery                                         1380
# Block Print                                             1055
# Screen Print                                             522
# Machine Embroidery                                       377
# Hand Paint                                               208
# Nakshi Kantha Embroidery                                 163
# Tie & Dye                                                122
# Machine Applique                                         118
# Batik Print                                               40
# Erri Embroidery                                           40
# Hand Applique                                             33
# Exclusive Hand Embroidery                                 26
# Digital Print                                              6
# Cylinder Dye                                               3
# Brush Paint                                                3
# Fountain Dye                                               3
# Acid Dye                                                   1
# Glass Fitting, Hand Embroidery, Screen Print, Sequin       1
# Name: count, dtype: int64

# %%
fabric_mapping = {
    "Cotton": "Cotton",
	"Cotton Knit": "Cotton",
    "Handloom Cotton": "Cotton",
    "Vortex-Cotton": "Cotton",
    "Vortex Cotton": "Cotton",
    "Ramie Cotton": "Cotton",

    "Mixed Cotton": "Cotton Blend",
    "Cottray (Cotton & Rayon)": "Cotton Blend",

    "Single Jersey Knit Cotton": "Cotton",
    
	"Muslin": "Muslin",
    "Endi Muslin": "Muslin",
    "Mixed Muslin (Muslin & Endi)": "Muslin",
    "Blended Muslin (Muslin & Silk)": "Muslin",
    "Mixed Muslin": "Muslin",
	"Muslin Blend": "Muslin",

    "Silk": "Silk",
    "Soft Silk": "Silk",
    "Dupion Silk": "Silk",
    "Joysree Silk": "Silk",
    "Katan": "Silk",
    "Endi Silk": "Silk",

    "Endi Silk-Muslin": "Silk Blend",
    "Half Silk (Silk & Cotton)": "Silk Blend",
    "Mixed Silk (Silk & Cotton)": "Silk Blend",
    "Jamdani Half Silk (Silk & Cotton)": "Silk Blend",
    "SICO (Silk & Cotton)": "Silk Blend",
    "Mixed Silk": "Silk Blend",

    "Viscose": "Viscose",
    "Jacquard Viscose": "Viscose",
    "Handloom Viscose": "Viscose",

    "Mixed Viscose": "Viscose Blend",
    "Viscott (Viscose & Cotton)": "Viscose Blend",

    "Linen": "Linen",

    "Satin": "Satin",
    "Satin Cotton": "Satin",

    "Georgette": "Georgette",
    "Poplin": "Poplin",
    "Denim": "Denim",

    "Mixed Vortex": "Blended Fabric",
    "Addi Cotton": "Blended Fabric",
    
	"Cashmilon": "Synthetic",
    "Wool": "Wool"
}


lost = fabric_mapping.keys() - set(fabric_mapping.values())

lost
# Out:
# {'Addi Cotton',
#  'Blended Muslin (Muslin & Silk)',
#  'Cashmilon',
#  'Cotton Knit',
#  'Cottray (Cotton & Rayon)',
#  'Dupion Silk',
#  'Endi Muslin',
#  'Endi Silk',
#  'Endi Silk-Muslin',
#  'Half Silk (Silk & Cotton)',
#  'Handloom Cotton',
#  'Handloom Viscose',
#  'Jacquard Viscose',
#  'Jamdani Half Silk (Silk & Cotton)',
#  'Joysree Silk',
#  'Katan',
#  'Mixed Cotton',
#  'Mixed Muslin',
#  'Mixed Muslin (Muslin & Endi)',
#  'Mixed Silk',
#  'Mixed Silk (Silk & Cotton)',
#  'Mixed Viscose',
#  'Mixed Vortex',
#  'Muslin Blend',
#  'Ramie Cotton',
#  'SICO (Silk & Cotton)',
#  'Satin Cotton',
#  'Single Jersey Knit Cotton',
#  'Soft Silk',
#  'Viscott (Viscose & Cotton)',
#  'Vortex Cotton',
#  'Vortex-Cotton'}

# %%
set(fabric_mapping.values())
# Out:
# {'Blended Fabric',
#  'Cotton',
#  'Cotton Blend',
#  'Denim',
#  'Georgette',
#  'Linen',
#  'Muslin',
#  'Poplin',
#  'Satin',
#  'Silk',
#  'Silk Blend',
#  'Synthetic',
#  'Viscose',
#  'Viscose Blend',
#  'Wool'}

# %%
fabric_raw_label_counts = df['specs.Fabric'].value_counts()

fabric_mapped_label_counts = {}

# for each raw fabric label, find the mapped label and add the count to the mapped label

for raw_label, count in fabric_raw_label_counts.items():
	mapped_label = fabric_mapping.get(raw_label, None)
	if mapped_label:
		fabric_mapped_label_counts[mapped_label] = fabric_mapped_label_counts.get(mapped_label, 0) + count


# print(f"Raw Fabric Label Counts:")
# print(fabric_raw_label_counts.to_frame())

print(f"\nMapped Fabric Label Counts:")
for k, v in fabric_mapped_label_counts.items():
	print(f"{k}: {v}")
# Out:
# Mapped Fabric Label Counts:
# Cotton: 2040
# Viscose Blend: 745
# Silk: 814
# Viscose: 699
# Muslin: 410
# Silk Blend: 181
# Linen: 78
# Cotton Blend: 43
# Synthetic: 14
# Poplin: 11
# Blended Fabric: 11
# Wool: 7
# Georgette: 1
# Satin: 2
# Denim: 1

# %% [markdown]
# ## Fabric Classes
#
# Above cells show the

# %% [markdown]
# ---

# %%
# All rows where title contains "floral"

df[df['description'].str.contains("floral", case=False, na=False)]
# Out:
#         id   category sub_category  \
# 0        1      Saree       Cotton
# 6        7      Saree       Cotton
# 49      50      Saree       Cotton
# 50      51      Saree       Cotton
# 52      53      Saree       Cotton
# ...    ...        ...          ...
# 5213  7976  Nightwear          N/A
# 5219  7982  Nightwear          N/A
# 5230  7993  Nightwear          N/A
# 5250  8013  Nightwear          N/A
# 5273  8036  Nightwear          N/A
#
#                                                   title  \
# 0            White Printed and Embroidered Cotton Saree
# 6          Magenta Printed and Embroidered Cotton Saree
# 49    White/Orange Printed And Embroidered Cotton Saree
# 50                           Green Printed Cotton Saree
# 52                      Light Cyan Printed Cotton Saree
# ...                                                 ...
# 5213              Midnight Blue Printed Voile Nightwear
# 5219  Dusty Pink Printed and Embroidered Voile Night...
# 5230                      Rust Printed Cotton Nightwear
# 5250  Peach Printed and Embroidered Voile Nightwear Set
# 5273               Deep Brown Printed Cotton Long Dress
#
#                                             description  \
# 0     White printed cotton saree with floral embroid...
# 6     Magenta printed cotton saree with floral embro...
# 49    White cotton saree with multicolour floral pri...
# 50    Green cotton saree with multicolour floral pri...
# 52    Light cyan cotton saree with multicolour flora...
# ...                                                 ...
# 5213  Midnight blue voile nightwear with multicolour...
# 5219  Dusty pink printed voile nightwear with floral...
# 5230  Rust cotton nightwear with floral prints. Come...
# 5250  Peach voile nightwear with embroidery. Comes w...
# 5273  Deep brown cotton long dress with multicolour ...
#
#                                                  images specs.Colour  \
# 0     [https://www.aarong.com/media/catalog/product/...        White
# 6     [https://www.aarong.com/media/catalog/product/...      Magenta
# 49    [https://www.aarong.com/media/catalog/product/...        White
# 50    [https://www.aarong.com/media/catalog/product/...        Green
# 52    [https://www.aarong.com/media/catalog/product/...         Cyan
# ...                                                 ...          ...
# 5213  [https://www.aarong.com/media/catalog/product/...         Blue
# 5219  [https://www.aarong.com/media/catalog/product/...         Pink
# 5230  [https://www.aarong.com/media/catalog/product/...        Brown
# 5250  [https://www.aarong.com/media/catalog/product/...       Orange
# 5273  [https://www.aarong.com/media/catalog/product/...        Brown
#
#      specs.Fabric specs.Value Addition specs.Cut /Fit specs.Collar/Neck  \
# 0          Cotton      Hand Embroidery            NaN               NaN
# 6          Cotton   Machine Embroidery            NaN               NaN
# 49         Cotton      Hand Embroidery            NaN               NaN
# 50         Cotton         Screen Print            NaN               NaN
# 52         Cotton         Screen Print            NaN               NaN
# ...           ...                  ...            ...               ...
# 5213        Voile                  NaN         Flared        Round Neck
# 5219        Voile      Hand Embroidery         Flared        Round Neck
# 5230        Voile         Screen Print         A-Line        Round Neck
# 5250        Voile      Hand Embroidery         A-Line        Round Neck
# 5273       Cotton                  NaN         A-Line      Frill Collar
#
#           specs.Sleeve specs.Bottom Colour specs.Bottom Fabric  \
# 0                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 49                 NaN                 NaN                 NaN
# 50                 NaN                 NaN                 NaN
# 52                 NaN                 NaN                 NaN
# ...                ...                 ...                 ...
# 5213       Half Sleeve                 NaN                 NaN
# 5219      Short Sleeve                 NaN                 NaN
# 5230       Half Sleeve                 NaN                 NaN
# 5250  3-Quarter Sleeve                 NaN                 NaN
# 5273      Short Sleeve                 NaN                 NaN
#
#      specs.Dupatta Colour specs.Dupatta Fabric
# 0                     NaN                  NaN
# 6                     NaN                  NaN
# 49                    NaN                  NaN
# 50                    NaN                  NaN
# 52                    NaN                  NaN
# ...                   ...                  ...
# 5213                  NaN                  NaN
# 5219                  NaN                  NaN
# 5230                  NaN                  NaN
# 5250                  NaN                  NaN
# 5273                  NaN                  NaN
#
# [108 rows x 16 columns]

# %%
# Save id and title as a csv

df[['id', 'title', 'description']].to_csv('../../data/id-title-description.csv', index=False)

# %%
# Get all the titles as list
titles = df['title'].tolist()[:20]

print(titles)
# Out:
# ['White Printed and Embroidered Cotton Saree', 'Peach Printed Cotton Saree', 'Light Pink Printed Cotton Saree', 'Peach Appliqued and Embroidered Cotton Saree', 'Magenta Printed and Embroidered Cotton Saree', 'Maroon Wax Dyed and Printed Cotton Saree', 'Dark Red Printed and Embroidered Cotton Saree', 'Red Printed And Embroidered Cotton Saree', 'Dark Magenta Printed Cotton Saree', 'Pink Printed Cotton Saree', 'Pink Printed and Embroidered Cotton Saree', 'Multicolour Sand Splash Dyed and Printed Cotton Saree', 'Purple Printed And Embroidered Cotton Saree', 'Pastel Green Printed Cotton Saree', 'Brown Printed And Embroidered Cotton Saree', 'White/Orange Printed Cotton Saree', 'Peach/Mustard Wax Dyed and Brush Painted Cotton Saree', 'Grey Sand Splash Dyed and Brush Painted Cotton Saree', 'Hot Pink Appliqued and Embroidered Cotton Saree', 'Ivory Printed Cotton Saree', 'Yellow Printed Cotton Saree', 'Yellow Appliqued and Embroidered Cotton Saree', 'Yellow Printed Cotton Saree', 'Mustard Printed Cotton Saree', 'Parrot Green Printed Cotton Saree', 'Green Tie-Dyed Printed and Embroidered Cotton Saree', 'Golden Yellow Printed and Embroidered Cotton Saree', 'Charcoal Grey Appliqued and Embroidered Cotton Saree', 'Beige Printed and Wax Dyed Cotton Saree', 'Dark Pine Green Appliqued Cotton Saree', 'Dusty Pink/Red Appliqued and Embroidered Cotton Saree', 'Black Pabna Cotton Kotki Saree', 'Aquamarine/Purple Striped Tangail Cotton Saree', 'Pink Striped Tangail Cotton Nakshi Par Saree', 'Pink Pabna Cotton Saree', 'Purple/Blue Striped Tangail Cotton Saree', 'Olive Tangail Cotton Shambalpuri Saree', 'Navy Blue Pabna Cotton Baluchari Saree', 'Off White Tangail Cotton Nakshi Par Saree', 'Maroon Tangail Cotton Shambalpuri Saree', 'Maroon Pabna Cotton Baluchari Saree', 'Slate Blue Tangail Cotton Nakshi Par Saree', 'Magenta Brush Painted and Printed Cotton Saree', 'Red Printed And Embroidered Cotton Saree', 'Red Printed And Embroidered Cotton Saree', 'Red Printed And Hand Painted Cotton Saree', 'Peach Printed Cotton Saree', 'White/Orange Printed And Embroidered Cotton Saree', 'Green Printed Cotton Saree', 'Green Striped and Printed Cotton Saree', 'Light Cyan Printed Cotton Saree', 'Slate Blue Striped Tangail Cotton Saree', 'White Dyed and Printed Cotton Saree', 'Orange Tangail Cotton Saree', 'Orange Sirajganj Cotton Opera Saree', 'Brown Striped Tangail Cotton Saree', 'Orange Striped and Printed Cotton Saree', 'Peach Printed Cotton Saree', 'Beige Printed Cotton Saree', 'Lemon Yellow Pabna Cotton Nakshi Par Saree', 'Magenta Printed and Embroidered Cotton Saree', 'Magenta Tangail Cotton Hand Buti Saree', 'Pink Printed Cotton Saree', 'Purple Sirajganj Cotton Opera Saree', 'Orange Printed Cotton Saree', 'Fire Orange Printed Cotton Saree', 'Peach Tangail Cotton Nakshi Par Saree', 'Peach Printed and Embroidered Cotton Saree', 'White Pabna Cotton Nakshi Par Saree', 'Peach Tangail Cotton Nakshi Par Saree', 'Beige Stripe Tangail Cotton Saree', 'Plum Appliqued and Embroidered Cotton Saree', 'Brown Check Tangail Cotton Saree', 'Light Brown Printed Cotton Saree', 'Burnt Orange Tangail Cotton Nakshi Par Saree', 'Beige Printed And Embroidered Cotton Saree', 'Blue Tangail Cotton Saree', 'Midnight Blue Printed and Embroidered Cotton Saree', 'Blue Printed Cotton Saree', 'Teal Green Striped Tangail Cotton Saree', 'Teal Striped Tangail Cotton Nakshi Par Saree', 'Off White Sand Splash Dyed and Printed Cotton Saree', 'Off White Printed Cotton Saree', 'Lilac Printed and Embroidered Cotton Saree', 'Midnight Blue/Burgundy Tangail Cotton Baluchari Saree', 'Magenta Tangail Cotton Baluchari Saree', 'Pink Tangail Cotton Nakshi Par Saree', 'Mustard Pabna Cotton Saree', 'Olive Printed and Embroidered Cotton Saree', 'Yellow Ochre/Teal Check Pabna Cotton Nakshi Par Saree', 'Light Brown Printed Cotton Saree', 'Sharp Green Tangail Cotton Saree', 'Beige Appliqued and Embroidered Cotton Saree', 'Light Brown Printed and Embroidered Cotton Saree', 'Purple/Green Tangail Cotton Baluchari Sare ...

# %%
# Get id and title as list of tuples
#id_title = df[['id', 'title', 'description', 'images']].values.tolist()[:2]

#id_title
# Out:
# [[1,
#   'White Printed and Embroidered Cotton Saree',
#   'White printed cotton saree with floral embroidery. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   ['https://www.aarong.com/media/catalog/product/0/5/0560000072957.jpg?optimize=high&bg-color=255,255,255&fit=bounds&height=667&width=500&canvas=500:667',
#    'https://www.aarong.com/media/catalog/product/0/5/0560000072957_2.jpg?optimize=high&bg-color=255,255,255&fit=bounds&height=667&width=500&canvas=500:667',
#    'https://www.aarong.com/media/catalog/product/0/5/0560000072957_1.jpg?optimize=high&bg-color=255,255,255&fit=bounds&height=667&width=500&canvas=500:667']],
#  [4,
#   'Peach Printed Cotton Saree',
#   'Peach cotton saree with multicolour prints. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   ['https://www.aarong.com/media/catalog/product/0/5/0560000072382.jpg?optimize=high&bg-color=255,255,255&fit=bounds&height=667&width=500&canvas=500:667',
#    'https://www.aarong.com/media/catalog/product/0/5/0560000072382_2.jpg?optimize=high&bg-color=255,255,255&fit=bounds&height=667&width=500&canvas=500:667',
#    'https://www.aarong.com/media/catalog/product/0/5/0560000072382_1.jpg?optimize=high&bg-color=255,255,255&fit=bounds&height=667&width=500&canvas=500:667']]]

# %%
new_df = df[['id', 'title', 'description', 'images']]

# Explode images

#new_df['eval_images'] = new_df['images'].apply(eval)

new_df.explode('images', ignore_index=True)
# Out:
#          id                                              title  \
# 0         1         White Printed and Embroidered Cotton Saree
# 1         1         White Printed and Embroidered Cotton Saree
# 2         1         White Printed and Embroidered Cotton Saree
# 3         4                         Peach Printed Cotton Saree
# 4         4                         Peach Printed Cotton Saree
# ...     ...                                                ...
# 13611  8046                      Pink Tie-Dyed Voile Nightwear
# 13612  8047  Light Purple Tie-Dyed and Embroidered Voile Ni...
# 13613  8047  Light Purple Tie-Dyed and Embroidered Voile Ni...
# 13614  8048          Blue Tie-Dyed and Printed Voile Nightwear
# 13615  8048          Blue Tie-Dyed and Printed Voile Nightwear
#
#                                              description  \
# 0      White printed cotton saree with floral embroid...
# 1      White printed cotton saree with floral embroid...
# 2      White printed cotton saree with floral embroid...
# 3      Peach cotton saree with multicolour prints. Co...
# 4      Peach cotton saree with multicolour prints. Co...
# ...                                                  ...
# 13611  Pink and purple tie-dyes voile nightwear with ...
# 13612  Light purple and white tie-dyed voile nightwea...
# 13613  Light purple and white tie-dyed voile nightwea...
# 13614  Blue printed and tie-dyed voile nightwear with...
# 13615  Blue printed and tie-dyed voile nightwear with...
#
#                                                   images
# 0      https://www.aarong.com/media/catalog/product/0...
# 1      https://www.aarong.com/media/catalog/product/0...
# 2      https://www.aarong.com/media/catalog/product/0...
# 3      https://www.aarong.com/media/catalog/product/0...
# 4      https://www.aarong.com/media/catalog/product/0...
# ...                                                  ...
# 13611  https://www.aarong.com/media/catalog/product/0...
# 13612  https://www.aarong.com/media/catalog/product/0...
# 13613  https://www.aarong.com/media/catalog/product/0...
# 13614  https://www.aarong.com/media/catalog/product/0...
# 13615  https://www.aarong.com/media/catalog/product/0...
#
# [13616 rows x 4 columns]

# %%
# type of images column

new_df['images'].dtype
# Out:
# dtype('O')

# %%
# get list of unique categories
a = df['specs.Bottom Colour'].unique().tolist()

b = df['specs.Dupatta Colour'].unique().tolist()

c = df['specs.Colour'].unique().tolist()

all = a + b + c

# remove duplicates
all = list(dict.fromkeys(all))

print(all)
# Out:
# [nan, 'Olive Green', 'Onion Pink', 'White', 'Blue', 'Mustard', 'Pink', 'Stone Blue', 'Multicolour', 'Black', 'Pastel Green', 'Brick Red', 'Fire Orange', 'Yellow Ochre', 'Grey', 'Green', 'Brown', 'Turquoise', 'Dark Olive', 'Orange', 'Peach', 'Sky Blue', 'Blue Grey', 'Seafoam Green', 'Light Green', 'Burgundy', 'Beige', 'Light Lavender', 'Yellow', 'Lavender', 'Lime Green', 'Plum', 'Navy Blue', 'Coral', 'Cider', 'Sage Green', 'Dark Grey', 'Pastel Yellow', 'Strawberry Red', 'Red', 'Maroon', 'Off White', 'Khaki', 'Ivory', 'Olive', 'Burnt Orange', 'Deep Pink', 'Teal', 'Deep Fuchsia', 'Fuchsia', 'Crimson Red', 'Moss Green', 'Lilac', 'Light Khaki', 'Bottle Green', 'Coffee', 'Purple', 'Cyan', 'Deep Peach', 'Light Brown', 'Sienna', 'Dark Teal', 'Pastel Orange', 'Moonlight Blue', 'Watermelon', 'Ecru', 'Hot Pink', 'Twilight Blue', 'Golden', 'Light Peach', 'Honey Mustard', 'Desert Dust', 'Pale Yellow', 'Lemon Yellow', 'Light Mauve', 'Mulberry', 'Sunny Lime', 'Mint Blue', 'Mauve', 'Magenta', 'Light Pink', 'Rust', 'Mint Green', 'Midnight Blue', 'Aqua']

# %%
# get list of unique categories
a = df['specs.Fabric'].unique().tolist()

b = df['specs.Bottom Fabric'].unique().tolist()

c = df['specs.Dupatta Fabric'].unique().tolist()

d = df['sub_category'].unique().tolist()

all = a + b + c + d

# remove duplicates
all = list(dict.fromkeys(all))

# print(len(a))
# print(len(b))
# print(len(c))
# print(len(d))

print(all)
# Out:
# ['Cotton', 'Muslin', 'Silk', 'Endi Muslin', 'Mixed Muslin (Muslin & Endi)', 'Soft Silk', 'Half Silk (Silk & Cotton)', 'Endi Silk', 'Mixed Silk (Silk & Cotton)', 'Dupion Silk', 'Katan', 'Mixed Cotton', 'Jamdani Half Silk (Silk & Cotton)', 'Viscott (Viscose & Cotton)', 'Viscose', 'Voile', 'Vortex-Cotton', 'Handloom Cotton', 'Jacquard Viscose', 'Vortex Cotton', 'Mixed Viscose', 'Cottray (Cotton & Rayon)', 'Handloom Viscose', 'Ramie Cotton', 'Mixed Silk', 'Joysree Silk', 'Blended Muslin (Muslin & Silk)', 'Mixed Muslin', 'Endi Silk-Muslin', 'Linen', 'Satin', 'SICO (Silk & Cotton)', 'Cashmilon', 'Satin Cotton', 'Wool', nan, 'Georgette', 'Poplin', 'Mixed Vortex', 'Addi Cotton', 'Single Jersey Knit Cotton', 'Denim', 'Sico (Silk & Cotton)', 'Jacquard Cotton', 'Blended Muslin (Muslin+Silk+Endi)', 'Nakshi Kantha', 'Jamdani', 'Brac Silk', 'Casual', 'Semi-Dressy', 'Exclusive', 'Tops', 'Tunics', 'Dresses', 'Pants', 'Sleepwears', '3-Piece Sets', 'Blouse Pieces', 'Yokes', 'N/A']

# %%
import re

unique_prefix_counts = {}
unique_suffix_counts = {}

for line in lines:
	# Find all occurrences of "texture" or "textured" and capture the previous and next words
	matches = re.findall(r'(\w+)\s+(nakshi?)\s+(\w+)', line)
	for match in matches:
		previous_word = match[0]
		next_word = match[2]
		#print(f"{previous_word} {match[1]} {next_word} ")

		# Count unique prefixes and suffixes
		if previous_word not in unique_prefix_counts:
			unique_prefix_counts[previous_word] = 0
		unique_prefix_counts[previous_word] += 1
		if next_word not in unique_suffix_counts:
			unique_suffix_counts[next_word] = 0
		unique_suffix_counts[next_word] += 1

# Print the counts of unique prefixes and suffixes
print("Unique Prefix Counts:")

df_prefix_counts = pd.DataFrame(unique_prefix_counts.items(), columns=['Prefix', 'Count'])
df_suffix_counts = pd.DataFrame(unique_suffix_counts.items(), columns=['Suffix', 'Count'])

df_prefix_counts.sort_values(by='Count', ascending=False)[:20]

# for prefix, count in unique_prefix_counts.items():
# 	print(f"{prefix}: {count}")

# print("\nUnique Suffix Counts:")
# for suffix, count in unique_suffix_counts.items():
# 	print(f"{suffix}: {count}")
# Out:
# Unique Prefix Counts:
#     Prefix  Count
# 5       of      6
# 0    brown      3
# 1      red      1
# 2     aqua      1
# 3   copper      1
# 4    olive      1
# 6   yellow      1
# 7    green      1
# 8     blue      1
# 9     pink      1
# 10    with      1

# %%
df_suffix_counts.sort_values(by='Count', ascending=False)[:20]
# Out:
#    Suffix  Count
# 0  kantha     18
