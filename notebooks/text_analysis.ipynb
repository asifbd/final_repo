# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
import os
import mysql.connector

conn = mysql.connector.connect(host=os.getenv("MYSQL_HOST") , user=os.getenv("MYSQL_USER"), password=os.getenv("MYSQL_PASSWORD"), database=os.getenv("MYSQL_DB"), auth_plugin='mysql_native_password')

cursor = conn.cursor()

# %%
import pandas as pd

def get_annotable_items():
	query = """ 
			SELECT p.id, p.product_name, p.category, p.sub_category, r.details 
			FROM products p 
			JOIN raw_details r ON p.id = r.product_id
			JOIN annotation_status a on p.id=a.product_id
			WHERE a.flagged = 0;
			"""
	
	cursor.execute(query)
	
	rows = cursor.fetchall()
	columns = [i[0] for i in cursor.description]

	df = pd.DataFrame(rows, columns=columns)
	df_normalized = pd.json_normalize(df['details'].apply(eval))
	df = pd.concat([df, df_normalized], axis=1)

	df = df[[
		'id',
		'category',
		'sub_category',
		'title',
		'description',
		'images',
		'specs.Colour',
		'specs.Fabric',
		'specs.Value Addition',
		'specs.Cut /Fit',
		'specs.Collar/Neck',
		'specs.Sleeve',
		'specs.Bottom Colour',
		'specs.Bottom Fabric',
		'specs.Dupatta Colour',
		'specs.Dupatta Fabric'
	]]

	return df

# %%
df = get_annotable_items()

df
# Out:
#         id   category sub_category  \
# 0        1      Saree       Cotton
# 1        2      Saree       Cotton
# 2        3      Saree       Cotton
# 3        4      Saree       Cotton
# 4        5      Saree       Cotton
# ...    ...        ...          ...
# 5281  8044  Nightwear          N/A
# 5282  8045  Nightwear          N/A
# 5283  8046  Nightwear          N/A
# 5284  8047  Nightwear          N/A
# 5285  8048  Nightwear          N/A
#
#                                                   title  \
# 0            White Printed and Embroidered Cotton Saree
# 1                            Ivory Printed Cotton Saree
# 2            White Printed And Embroidered Cotton Saree
# 3                            Peach Printed Cotton Saree
# 4                       Light Pink Printed Cotton Saree
# ...                                                 ...
# 5281                 Stone Blue Printed Voile Nightwear
# 5282                     White Tie-Dyed Voile Nightwear
# 5283                      Pink Tie-Dyed Voile Nightwear
# 5284  Light Purple Tie-Dyed and Embroidered Voile Ni...
# 5285          Blue Tie-Dyed and Printed Voile Nightwear
#
#                                             description  \
# 0     White printed cotton saree with floral embroid...
# 1     Ivory cotton saree with golden, red, beige, ma...
# 2     White printed cotton saree with orange and red...
# 3     Peach cotton saree with multicolour prints. Co...
# 4     Light pink cotton saree with orange, pink, pur...
# ...                                                 ...
# 5281  Stone blue printed voile nightwear with matchi...
# 5282  White and green tie-dyes voile nightwear with ...
# 5283  Pink and purple tie-dyes voile nightwear with ...
# 5284  Light purple and white tie-dyed voile nightwea...
# 5285  Blue printed and tie-dyed voile nightwear with...
#
#                                                  images specs.Colour  \
# 0     [https://www.aarong.com/media/catalog/product/...        White
# 1     [https://www.aarong.com/media/catalog/product/...        White
# 2     [https://www.aarong.com/media/catalog/product/...        White
# 3     [https://www.aarong.com/media/catalog/product/...       Orange
# 4     [https://www.aarong.com/media/catalog/product/...         Pink
# ...                                                 ...          ...
# 5281  [https://www.aarong.com/media/catalog/product/...         Blue
# 5282  [https://www.aarong.com/media/catalog/product/...        White
# 5283  [https://www.aarong.com/media/catalog/product/...         Pink
# 5284  [https://www.aarong.com/media/catalog/product/...       Purple
# 5285  [https://www.aarong.com/media/catalog/product/...         Blue
#
#      specs.Fabric specs.Value Addition specs.Cut /Fit specs.Collar/Neck  \
# 0          Cotton      Hand Embroidery            NaN               NaN
# 1          Cotton         Screen Print            NaN               NaN
# 2          Cotton      Hand Embroidery            NaN               NaN
# 3          Cotton         Screen Print            NaN               NaN
# 4          Cotton         Screen Print            NaN               NaN
# ...           ...                  ...            ...               ...
# 5281        Voile          Block Print   Kaftan Style        Round Neck
# 5282        Voile         Screen Print   Kaftan Style        Round Neck
# 5283        Voile         Screen Print   Kaftan Style        Round Neck
# 5284        Voile   Machine Embroidery         A-Line       Square Neck
# 5285        Voile          Block Print        Pleated       Square Neck
#
#        specs.Sleeve specs.Bottom Colour specs.Bottom Fabric  \
# 0               NaN                 NaN                 NaN
# 1               NaN                 NaN                 NaN
# 2               NaN                 NaN                 NaN
# 3               NaN                 NaN                 NaN
# 4               NaN                 NaN                 NaN
# ...             ...                 ...                 ...
# 5281   Short Sleeve                 NaN                 NaN
# 5282  Kaftan Sleeve                 NaN                 NaN
# 5283  Kaftan Sleeve                 NaN                 NaN
# 5284   Short Sleeve                 NaN                 NaN
# 5285   Short Sleeve                 NaN                 NaN
#
#      specs.Dupatta Colour specs.Dupatta Fabric
# 0                     NaN                  NaN
# 1                     NaN                  NaN
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
# ...                   ...                  ...
# 5281                  NaN                  NaN
# 5282                  NaN                  NaN
# 5283                  NaN                  NaN
# 5284                  NaN                  NaN
# 5285                  NaN                  NaN
#
# [5286 rows x 16 columns]

# %%
# rows where title or description is null or empty

df[(df['title'].isnull()) | (df['title'] == '') | (df['description'].isnull()) | (df['description'] == '')]
# Out:
# Empty DataFrame
# Columns: [id, category, sub_category, title, description, images, specs.Colour, specs.Fabric, specs.Value Addition, specs.Cut /Fit, specs.Collar/Neck, specs.Sleeve, specs.Bottom Colour, specs.Bottom Fabric, specs.Dupatta Colour, specs.Dupatta Fabric]
# Index: []

# %%
# Take id, title, description to a new df

df_clean = df[['id', 'title', 'description']].copy()

df_clean.sample(2)
# Out:
#         id                                              title  \
# 1378  1379  Pastel Green Printed And Embroidered Muslin Saree
# 2186  2187  Grey Printed and Nakshi Kantha Embroidered Hal...
#
#                                             description
# 1378  Pastel green printed muslin saree with green, ...
# 2186  Grey printed half-silk saree with beige, brown...

# %%
import nltk

print(nltk.__version__)
# Out:
# 3.9.1

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

from nltk.stem import WordNetLemmatizer
from nltk import wordnet
nltk.download('wordnet')
nltk.download('punkt_tab')


stop_words = set(stopwords.words('english'))
wnl = WordNetLemmatizer()


def cleanup_text(text, return_as_tokens=False, lemmatize=False, remove_stop_words=True):
	if not isinstance(text, str):
		return ''
	
	text = text.lower()						# Lowercase the text

	text = re.sub(r'[^\w\s]', '', text)			# Remove punctuation

	tokens = word_tokenize(text)				# Tokenize the text

	if remove_stop_words:
		filtered_words = [word for word in tokens if word not in stop_words]	# Remove stop words
	else:
		filtered_words = tokens

	if lemmatize:
		filtered_words = [wnl.lemmatize(word) for word in filtered_words]		# Lemmatize words

	if return_as_tokens:
		return filtered_words
	else:
		return ' '.join(filtered_words)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\amahmud\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\amahmud\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
df_clean['title_clean'] = df_clean['title'].apply(lambda x: cleanup_text(x, lemmatize=True, remove_stop_words=True))
df_clean['description_clean'] = df_clean['description'].apply(lambda x: cleanup_text(x, lemmatize=True, remove_stop_words=True))

# %%
df_clean.sample(5)
# Out:
#         id                                              title  \
# 4558  7272               Brown Printed Viscose-Cotton Panjabi
# 2876  2879  White Printed and Embroidered Viscose-Cotton S...
# 2856  2859  Pink Printed and Embroidered Viscose Shalwar K...
# 1929  1930         Fuchsia Printed and Embroidered Silk Saree
# 2135  2136  Golden Printed and Nakshi Kantha Embroidered S...
#
#                                             description  \
# 4558  Brown viscose-cotton panjabi with black and go...
# 2876  White textured printed viscose-cotton kameez w...
# 2856  Pink printed dobby textured viscose kameez wit...
# 1929  Fuchsia printed silk saree with multicolour em...
# 2135  Golden printed silk saree with salmon pink, re...
#
#                                             title_clean  \
# 4558                brown printed viscosecotton panjabi
# 2876  white printed embroidered viscosecotton shalwa...
# 2856    pink printed embroidered viscose shalwar kameez
# 1929             fuchsia printed embroidered silk saree
# 2135  golden printed nakshi kantha embroidered silk ...
#
#                                       description_clean
# 4558     brown viscosecotton panjabi black golden print
# 2876  white textured printed viscosecotton kameez mu...
# 2856  pink printed dobby textured viscose kameez tea...
# 1929  fuchsia printed silk saree multicolour embroid...
# 2135  golden printed silk saree salmon pink red wate...

# %%
from collections import Counter
import re


# Apply cleanup and get tokenized workds for description
description_words = df['description'].apply(lambda x: cleanup_text(x, return_as_tokens=True, lemmatize=False, remove_stop_words=True))

all_words = []
for words in description_words:
	all_words.extend(words)

len(all_words)
# Out:
# 92241

# %%
word_freq = Counter(all_words)

# %%
word_freq.most_common(20)
# Out:
# [('blouse', 4593),
#  ('saree', 4405),
#  ('comes', 2989),
#  ('matching', 2721),
#  ('cotton', 2684),
#  ('printed', 2376),
#  ('piece', 2323),
#  ('unstitched', 2304),
#  ('photo', 2287),
#  ('part', 2287),
#  ('shown', 2286),
#  ('styling', 2286),
#  ('suggestion', 2286),
#  ('actual', 2286),
#  ('product', 2285),
#  ('embroidery', 2132),
#  ('green', 1956),
#  ('prints', 1929),
#  ('attached', 1573),
#  ('end', 1573)]

# %%
# Number of words with frequency > 10

len([k for k, v in word_freq.items() if v > 10])
# Out:
# 247

# %%
# Review those word frequencies to identify potential labels

wf = pd.DataFrame(word_freq.most_common(250), columns=['word', 'frequency'])

# %%
with pd.option_context('display.max_rows', 250):
    display(wf)

# %%
print(wf['word'].to_list())
# Out:
# ['blouse', 'saree', 'comes', 'matching', 'cotton', 'printed', 'piece', 'unstitched', 'photo', 'part', 'shown', 'styling', 'suggestion', 'actual', 'product', 'embroidery', 'green', 'prints', 'attached', 'end', 'blue', 'white', 'panjabi', 'silk', 'black', 'viscose', 'pink', 'viscosecotton', 'golden', 'brown', 'red', 'shalwar', 'orange', 'kameez', 'dupatta', 'yellow', 'weaving', 'purple', 'grey', 'textured', 'multicolour', 'crafted', 'district', 'bangladesh', 'origin', 'tangail', 'muslin', 'beige', 'light', 'magenta', 'casual', 'teal', 'maternity', 'sirajganj', 'tunic', 'top', 'taaga', 'painted', 'voile', 'turquoise', 'peach', 'olive', 'tiedyed', 'details', 'scarf', 'maroon', 'whether', 'handloom', 'shades', 'pair', 'dyed', 'appliqued', 'elegant', 'nakshi', 'beautiful', 'day', 'outdoors', 'meetup', 'attire', 'presence', 'kurta', 'nightwear', 'mustard', 'accessories', 'hand', 'try', 'features', 'coral', 'pabna', 'half', 'silver', 'kantha', 'detailing', 'brush', 'katan', 'opera', 'baluchari', 'jacquard', 'striped', 'dark', 'mint', 'plum', 'dobby', 'endi', 'copper', 'joysree', 'tassels', 'trim', 'pastel', 'lace', 'coffee', 'ivory', 'floral', 'aqua', 'navy', 'lavender', 'wax', 'sage', 'dress', 'slate', 'dual', 'tone', 'lime', 'choice', 'deep', 'mauve', 'great', 'sequin', 'shawl', 'fringe', 'check', 'linen', 'embroidered', 'occasions', 'mirpur', 'rust', 'sleepwear', 'applique', 'dusty', 'aquamarine', 'par', 'cyan', 'watermelon', 'pant', 'buti', 'sky', 'poplin', 'erri', 'mixed', 'burgundy', 'chocolate', 'fuchsia', 'bottle', 'jamdani', 'salmon', 'aanchal', 'abdomen', 'support', 'onion', 'side', 'midnight', 'seafoam', 'skirt', 'burnt', 'detail', 'inner', 'days', 'pockets', 'work', 'style', 'brick', 'apricot', 'formal', 'sea', 'long', 'step', 'soft', 'parrot', 'chosha', 'baby', 'lilac', 'tassel', 'cobalt', 'rose', 'silkmuslin', 'inseam', 'bluegrey', 'ochre', 'sophistication', 'elevated', 'artistry', 'tales', 'tradition', 'jacket', 'hot', 'lemon', 'shambalpuri', 'violet', 'tiedye', 'dollar', 'perfect', 'fire', 'muslinsilk', 'charcoal', 'texture', 'wear', 'dressy', 'mirror', 'lining', 'youre', 'special', 'looking', 'periwinkle', 'royal', 'statement', 'dye', 'pistachio', 'mulberry', 'gift', 'someone', 'weaved', 'kotki', 'peacock', 'crimson', 'vortex', 'sand', 'stripe', 'eggplant', 'moss', 'ombre', 'coaty', 'cashmilon', 'tops', 'zip', 'beauty', 'gold', 'left', '0px', 'tunics', 'womens', 'splash', 'contrast', 'pale', 'stone', 'vortexcotton', 'muslinjoysree', 'opening', 'paint', 'tie', 'paar']

# %%
# Save wf to csv
wf.to_csv('../../data/word_freq_new.csv', index=False)

# %%
import re

def show_common_prefix_suffix(lines, word, top=20):
	unique_prefix_counts = {}
	unique_suffix_counts = {}

	unique_words = set()

	for line in lines:
		#matches = re.findall(r'(\w*)\s*(' + re.escape(word) + r'\w*)\s*(\w*)', line, re.IGNORECASE)
		matches = re.findall(r'(\w*)\s*([\w-]*' + re.escape(word) + r'\w*)\s*(\w*)', line, re.IGNORECASE)
		for match in matches:
			previous_word = match[0]
			next_word = match[2]
			#print(f"{previous_word} {match[1]} {next_word} ")

			# Count unique prefixes and suffixes
			if previous_word not in unique_prefix_counts:
				unique_prefix_counts[previous_word] = 0
			unique_prefix_counts[previous_word] += 1
			if next_word not in unique_suffix_counts:
				unique_suffix_counts[next_word] = 0
			unique_suffix_counts[next_word] += 1

			unique_words.add(match[1])

	df_prefix_counts = pd.DataFrame(unique_prefix_counts.items(), columns=['Prefix', 'Count'])
	df_suffix_counts = pd.DataFrame(unique_suffix_counts.items(), columns=['Suffix', 'Count'])

	print(f"Top {top} Prefixes:")
	print(df_prefix_counts.nlargest(top, 'Count').to_string(index=False))
	print(f"\nTop {top} Suffixes:")
	print(df_suffix_counts.nlargest(top, 'Count').to_string(index=False))

	print(f"\nUnique words: {unique_words}")

	#return df_prefix_counts, df_suffix_counts

# %%
target_word = 'navy'

samples = df[df['description'].str.contains(target_word, na=False, case=False) 
			 #& ~df['description'].str.contains('green', na=False, case=False)
			 #& ~df['specs.Colour'].str.contains('blue', na=False, case=False)
			 #& ~df['specs.Fabric'].str.contains('Cotton', na=False, case=False)
			 #& ~df['specs.Value Addition'].str.contains('sequin', na=False, case=False)
			 ][
				 #['id', 'description', 'specs.Colour', 'specs.Fabric', 'specs.Value Addition']
				 ['id', 'description', 'specs.Colour']
				 #['specs.Value Addition']
				 #['specs.Colour']
			]

#samples = df[df['description'].str.contains('dye', na=False, case=False)][['id', 'description', 'specs.Colour', 'specs.Fabric', 'specs.Value Addition']]

print(f"Total Match: {len(samples)}")
print(samples['id'][:20].to_list())

lines = samples['description'].to_list()
show_common_prefix_suffix(lines, target_word, 40)

samples[:200].to_dict(orient='records')
# Out:
# Total Match: 100
# [40, 121, 176, 310, 315, 392, 400, 410, 441, 462, 522, 539, 557, 570, 574, 615, 692, 786, 886, 1010]
# Top 40 Prefixes:
# Prefix  Count
#            67
#    and     18
#   with     16
#   this      1
#   over      1
#
# Top 40 Suffixes:
# Suffix  Count
#   blue    101
#   Blue      2
#
# Unique words: {'navy', 'Navy'}
# [{'id': 40,
#   'description': 'Navy blue Pabna cotton baluchari saree with weaving. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Pabna, Bangladesh.',
#   'specs.Colour': 'Blue'},
#  {'id': 121,
#   'description': 'Blue striped Tangail cotton saree with silver, navy blue and sage green weaving. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Tangail, Bangladesh.',
#   'specs.Colour': 'Blue'},
#  {'id': 176,
#   'description': 'Navy blue cotton saree with shades of green and yellow prints. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 310,
#   'description': 'Olive cotton saree with bottle green, magenta, navy blue, white and purple prints. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Olive'},
#  {'id': 315,
#   'description': 'Sage green cotton saree with teal, navy blue and brown prints. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Green'},
#  {'id': 392,
#   'description': 'Aqua cotton saree with mint green, navy blue and periwinkle prints. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Cyan'},
#  {'id': 400,
#   'description': 'Apricot cotton saree with white, navy blue and brown prints. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Yellow'},
#  {'id': 410,
#   'description': 'Navy blue printed cotton saree with golden embroidery. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 441,
#   'description': 'Pastel blue cotton saree with green, yellow, navy blue and grey prints. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 462,
#   'description': 'Lilac Tangail cotton hand buti saree with magenta, turquoise and navy blue weavings. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Tangail, Bangladesh.',
#   'specs.Colour': 'Purple'},
#  {'id': 522,
#   'description': 'Navy blue cotton saree with magenta, golden, pink and white. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 539,
#   'description': 'Deep pink Tangail cotton Nakshi par saree with navy blue, turquoise, golden and green weaving. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Tangail, Bangladesh.',
#   'specs.Colour': 'Pink'},
#  {'id': 557,
#   'description': 'Navy blue Tangail cotton shambalpuri saree with orange, red and silver weaving. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Tangail, Bangladesh.',
#   'specs.Colour': 'Blue'},
#  {'id': 570,
#   'description': 'Navy blue Tangail cotton baluchari saree with green, purple, magenta and silver weaving. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Tangail, Bangladesh.\n',
#   'specs.Colour': 'Blue'},
#  {'id': 574,
#   'description': 'Magenta Tangail cotton saree with turquoise, navy blue, green and silver weaving. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Tangail, Bangladesh.',
#   'specs.Colour': 'Magenta'},
#  {'id': 615,
#   'description': 'Navy blue tie-dye cotton saree with multicolour prints. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 692,
#   'description': 'Brown Tangail cotton baluchari saree with turquoise, red, navy blue weaving. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Tangail, Bangladesh.\n',
#   'specs.Colour': 'Brown'},
#  {'id': 786,
#   'description': 'Purple cotton saree with navy blue, dark pink, white and green prints. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Purple'},
#  {'id': 886,
#   'description': 'Light mint green cotton saree with aqua and navy blue prints. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Green'},
#  {'id': 1010,
#   'description': 'Navy blue appliqued cotton saree with grey, pink, beige, aqua, red prints and embroidery. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 1116,
#   'description': 'Navy blue cotton saree with grey and green prints . Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 1187,
#   'description': 'Navy blue applique cotton saree with green, pink and white prints. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 1332,
#   'description': 'Apricot brush painted muslin saree with red, orange, green and navy blue prints. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Orange'},
#  {'id': 1360,
#   'description': 'Purple tie-dyed endi muslin saree. Green, turquoise and teal embroidery from body to aanchal. Nautical blue joysree silk aanchal with mirror detail. Comes with navy blue unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Purple'},
#  {'id': 1406,
#   'description': 'Navy blue appliqued muslin saree with pink embroidery. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 1440,
#   'description': 'Navy blue and grey printed endi muslin saree with dark pink, purple embroidery. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 1464,
#   'description': 'Step into sophistication with this navy blue applique printed muslin saree, elevated by the artistry of green, red, magenta, orange and blue embroidery, weaving tales of tradition and style. Unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 1508,
#   'description': 'Navy blue muslin saree with embroidery over appliqued. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 1684,
#   'description': 'Magenta Tangail soft silk baluchari saree with navy blue, golden, black and pink weaving. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Tangail, Bangladesh.\n',
#   'specs.Colour': 'Magenta'},
#  {'id': 1685,
#   'description': 'Maroon and navy blue dual tone Tangail half-silk baluchari saree with magenta, orange and golden weaving. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Tangail, Bangladesh.',
#   'specs.Colour': 'Maroon'},
#  {'id': 1694,
#   'description': 'Lime green dyed silk saree with green, copper and navy blue prints. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Green'},
#  {'id': 1704,
#   'description': 'Teal appliqued silk saree with grey, navy blue, purple and deep pink embroidery. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 1768,
#   'description': 'Magenta soft silk Tangail baluchari saree with red, navy blue and silver weaving. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Tangail, Bangladesh.\n',
#   'specs.Colour': 'Magenta'},
#  {'id': 1988,
#   'description': 'Magenta Mirpur Katan saree with turquoise, navy blue and golden weaving. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Magenta'},
#  {'id': 1990,
#   'description': 'Purple and navy blue striped Mirpur katan saree with golden and green weaving. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Purple'},
#  {'id': 2007,
#   'description': 'Blue Tangail chosha katan saree with orange, magenta, navy blue and golden weaving. Comes with matching unstitched blouse piece attached at the end of saree. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.\nOrigin:\nThis saree is crafted in the district of Tangail, Bangladesh.',
#   'specs.Colour': 'Blue'},
#  {'id': 2087,
#   'description': 'Lavender printed silk saree with navy blue and chocolate Nakshi Kantha embroidery. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Purple'},
#  {'id': 2266,
#   'description': 'Navy blue half silk jamdani saree with turquoise, dark pink, mint green buti. Comes with matching unstitched blouse piece. Blouse shown in the photo is a styling suggestion, it is not a part of the actual product.',
#   'specs.Colour': 'Blue'},
#  {'id': 2377,
#   'description': 'Navy blue viscose kameez with white, beige, golden prints and embroidery. Comes with matching white printed viscose shalwar and matching white printed viscose dupatta with tassels.',
#   'specs.Colour': 'Blue'},
#  {'id': 2397,
#   'description': 'Purple printed cotton kameez with silver and green embroidery. Comes with navy blue cotton shalwar and navy blue printed cotton dupatta with tassels.',
#   'specs.Colour': 'Purple'},
#  {'id': 2541,
#   'description': 'Navy blue jacquard textured viscose-cotton kameez with silver and mustard yellow embroidery. Printed detail at ends. Comes with navy blue viscose-cotton shalwar and mustard yellow and blue printed dobby textured viscose-cotton dupatta.',
#   'specs.Colour': 'Blue'},
#  {'id': 2571,
#   'description': 'Navy blue viscose-cotton kameez with purple, blue and turquoise embroidery. Comes with matching printed cotton shalwar and matching printed viscose dupatta.',
#   'specs.Colour': 'Blue'},
#  {'id': 2646,
#   'description': 'Navy blue printed viscose-cotton kameez with embroidery. Comes with blue printed cotton shalwar. Features matching printed viscose-cotton dupatta.',
#   'specs.Colour': 'Blue'},
#  {'id': 2763,
#   'description': 'Peacock blue appliqued viscose-cotton kameez with sea green and navy blue embroidery. Comes with matching cotton shalwar and turquoise printed viscose-cotton dupatta with tassels.',
#   'specs.Colour': 'Blue'},
#  {'id': 2839,
#   'description': 'Teal printed viscose kameez with multicolour embroidery. Comes with navy blue cotton shalwar and teal printed viscose dupatta.',
#   'specs.Colour': 'Green'},
#  {'id': 2870,
#   'description': 'Plum jacquard textured viscose kameez with orange embroidery. Comes with navy blue viscose shalwar and navy blue printed viscose dupatta.',
#   'specs.Colour': 'Purple'},
#  {'id': 2912,
#   'description': 'Navy blue printed endi silk kameez with shades of red, rose gold, purple, brown and aqua embroidery. Comes with purple joysree silk shalwar and red/blue tie-dye printed muslin-silk dupatta with tassels.',
#   'specs.Colour': 'Blue'},
#  {'id': 2942,
#   'description': 'Navy blue endi silk kameez with shades of blue, green and brown embroidery. Comes with blue joysree silk shalwar and matching printed muslin silk dupatta with tassels.',
#   'specs.Colour': 'Blue'},
#  {'id': 3000,
#   'description': 'Blue and teal check silk kameez with black, copper and brown embroidery. Comes with navy blue joysree silk shalwar and teal printed silk dupatta with tassels.',
#   'specs.Colour': 'Blue'},
#  {'id': 3072,
#   'description': 'Blue viscose-cotton Taaga casual maternity top with green, navy blue and turquoise prints.',
#   'specs.Colour': 'Blue'},
#  {'id': 3102,
#   'description': 'Navy blue dobby textured viscose maternity top.',
#   'specs.Colour': 'Blue'},
#  {'id': 3127,
#   'description': 'Navy blue printed linen maternity casual tunic with blue and purple embroidery.',
#   'specs.Colour': 'Blue'},
#  {'id': 3139,
#   'description': 'Copper viscose Taaga maternity tunic with navy blue and copper embroidery.',
#   'specs.Colour': 'Brown'},
#  {'id': 3240,
#   'description': 'Deep mauve cotton casual maternity tunic with plum and navy blue embroidery.',
#   'specs.Colour': 'Purple'},
#  {'id': 3287,
#   'description': 'Navy blue wax-dyed viscose Taaga maternity dress with multicolour prints. Features in-seam side pockets.',
#   'specs.Colour': 'Blue'},
#  {'id': 3329,
#   'description': 'Navy blue cotton maternity pant with abdomen support.',
#   'specs.Colour': 'Blue'},
#  {'id': 3334,
#   'description': 'Navy blue cotton Taaga maternity pant with abdomen support.',
#   'specs.Colour': 'Blue'},
#  {'id': 3485,
#   'description': 'Sky blue and navy blue tie-dyed handloom viscose shawl. Comes with fringe trim.',
#   'specs.Colour': 'Blue'},
#  {'id': 3497,
#   'description': 'Orange, yellow, green and navy blue striped handloom viscose shawl with all over circular patterns.',
#   'specs.Colour': 'Brown'},
#  {'id': 3551,
#   'description': 'Navy Blue voile yoke with embroidery and glass detailing.',
#   'specs.Colour': 'Blue'},
#  {'id': 6287,
#   'description': 'Navy blue printed viscose-cotton kurta with embroidery.',
#   'specs.Colour': 'Blue'},
#  {'id': 6316,
#   'description': 'Navy blue texture printed viscose  kurta with brown, blue, golden and black embroidery.',
#   'specs.Colour': 'Blue'},
#  {'id': 6336,
#   'description': 'Teal blue and navy blue dyed brush painted viscose kurta with mint green embroidery.',
#   'specs.Colour': 'Blue'},
#  {'id': 6450,
#   'description': 'Ultra blue and navy blue wax dyed dobby textured rayon kurta brushed with black paint. Features in-seam side pockets.',
#   'specs.Colour': 'Blue'},
#  {'id': 6597,
#   'description': 'Navy blue and grey striped ramie cotton panjabi.',
#   'specs.Colour': 'Blue'},
#  {'id': 6664,
#   'description': "Mint green viscose-cotton panjabi with copper, navy blue and golden prints. Whether it's a beautiful day outdoors or a casual meet-up you can pair up with this attire to elegant your presence.",
#   'specs.Colour': 'Green'},
#  {'id': 6695,
#   'description': "Dark pink viscose panjabi with navy blue prints. Whether it's a beautiful day outdoors or a casual meet-up you can pair up with this attire to elegant your presence.",
#   'specs.Colour': 'Pink'},
#  {'id': 6732,
#   'description': 'Apricot cotton panjabi with golden and navy blue prints.',
#   'specs.Colour': 'Orange'},
#  {'id': 6733,
#   'description': 'Salmon pink cotton panjabi with golden and navy blue prints.',
#   'specs.Colour': 'Pink'},
#  {'id': 6759,
#   'description': 'Grey, navy blue and black check cotton panjabi.',
#   'specs.Colour': 'Grey'},
#  {'id': 6760,
#   'description': 'Navy blue cotton panjabi with teal prints.',
#   'specs.Colour': 'Blue'},
#  {'id': 6865,
#   'description': 'Navy blue viscose-cotton panjabi with black prints.',
#   'specs.Colour': 'Blue'},
#  {'id': 6890,
#   'description': 'Navy blue cotton panjabi with turquoise, green, golden and blue prints.',
#   'specs.Colour': 'Blue'},
#  {'id': 7055,
#   'description': 'Navy Blue cotton panjabi with turquoise prints.',
#   'specs.Colour': 'Blue'},
#  {'id': 7065,
#   'description': "Navy blue poplin panjabi with golden, light blue and coral prints. Whether it's a beautiful day outdoors or a casual meet-up you can pair up with this attire to elegant your presence.",
#   'specs.Colour': 'Blue'},
#  {'id': 7139,
#   'description': 'Navy blue viscose cotton panjabi with black prints',
#   'specs.Colour': 'Blue'},
#  {'id': 7404,
#   'description': 'Lilac printed viscose Taaga top with navy blue embroidery.',
#   'specs.Colour': 'Purple'},
#  {'id': 7488,
#   'description': 'Navy blue cotton Taaga casual skirt with sage green, grey and mauve prints.',
#   'specs.Colour': 'Blue'},
#  {'id': 7500,
#   'description': 'Slate grey viscose Taaga casual skirt with slate blue, navy blue and mauve prints.',
#   'specs.Colour': 'Grey'},
#  {'id': 7516,
#   'description': 'Navy blue viscose skirt with pink, mint green, golden and brown prints.',
#   'specs.Colour': 'Blue'},
#  {'id': 7522,
#   'description': 'Navy blue viscose skirt. Features inner elastic and front end button up.',
#   'specs.Colour': 'Blue'},
#  {'id': 7582,
#   'description': 'Navy blue, brown and red hand painted silk scarf. Try with panjabi or top or tunic and other accessories.',
#   'specs.Colour': 'Blue'},
#  {'id': 7625,
#   'description': 'Navy blue and white hand painted silk scarf. Try with panjabi or top or tunic and other accessories.',
#   'specs.Colour': 'Blue'},
#  {'id': 7651,
#   'description': 'Navy blue and blue hand painted silk scarf. Try with panjabi or top or tunic and other accessories.',
#   'specs.Colour': 'Blue'},
#  {'id': 7664,
#   'description': 'Navy blue and turquoise hand painted silk scarf. Try with panjabi or top or tunic and other accessories.',
#   'specs.Colour': 'Blue'},
#  {'id': 7666,
#   'description': 'Yellow, orange, navy blue and light green hand painted silk scarf. Try with panjabi or top or tunic and other accessories.',
#   'specs.Colour': 'Yellow'},
#  {'id': 7667,
#   'description': 'Green, sky blue, navy blue and white hand painted silk scarf. Try with panjabi or top or tunic and other accessories.',
#   'specs.Colour': 'Green'},
#  {'id': 7672,
#   'description': 'Green, rust and navy blue hand painted silk scarf. Try with panjabi or top or tunic and other accessories.',
#   'specs.Colour': 'Blue'},
#  {'id': 7687,
#   'description': 'Red, white and navy blue hand painted silk scarf. Try with panjabi or top or tunic and other accessories.',
#   'specs.Colour': 'Red'},
#  {'id': 7688,
#   'description': 'Green, navy blue and cyan hand painted silk scarf. Try with panjabi or top or tunic and other accessories.',
#   'specs.Colour': 'Green'},
#  {'id': 7707,
#   'description': 'Green, navy blue and magenta hand painted silk scarf. Try with panjabi or top or tunic and other accessories.',
#   'specs.Colour': 'Green'},
#  {'id': 7748,
#   'description': 'Navy blue, yellow and green hand painted silk scarf. Can pair it with panjabi or tops or tunics or other accessories.',
#   'specs.Colour': 'Blue'},
#  {'id': 7803,
#   'description': 'Navy blue voile long dress with slate blue and white embroidery.',
#   'specs.Colour': 'Blue'},
#  {'id': 7837,
#   'description': 'Navy blue voile nightwear with light grey and black embroidery. Features trim lace details.',
#   'specs.Colour': 'Blue'},
#  {'id': 7840,
#   'description': 'White printed voile long dress with white embroidery. Comes with navy blue voile pant.',
#   'specs.Colour': 'White'},
#  {'id': 7847,
#   'description': 'Navy blue voile nightwear with embroidery. Comes with blue printed voile shalwar.',
#   'specs.Colour': 'Blue'},
#  {'id': 7868,
#   'description': 'Orange printed nightwear with blue and orange embroidery. Comes with navy blue voile shalwar.',
#   'specs.Colour': 'Orange'},
#  {'id': 7950,
#   'description': 'Navy blue printed cotton nightwear with embroidery. Comes with white cotton shalwar.',
#   'specs.Colour': 'Blue'},
#  {'id': 7974,
#   'description': 'White and red cotton nightwear with navy blue prints.',
#   'specs.Colour': 'White'},
#  {'id': 8029,
#   'description': 'Yellow printed linen nightwear with yellow embroidery over navy blue panel. Comes with blue linen shalwar.',
#   'specs.Colour': 'Yellow'}]

# %%
# Out:
# Top 40 Prefixes:
#   Prefix  Count
#              11
#    Light      2
#     with      1
#      and      1
# matching      1
#
# Top 40 Suffixes:
#      Suffix  Count
#     printed      5
#     viscose      2
#      prints      1
#         red      1
#        silk      1
#     Tangail      1
#      purple      1
#  embroidery      1
# embroidered      1
#      cotton      1
#         and      1
#
# Unique words: {'mulberry', 'Mulberry'}
