# %% [markdown]
# This notebook is intended to experiment on different ways to encode the labels to understand which one makes sense.

# %%
# Load dataset

import pandas as pd

df = pd.read_csv('../../data/aarong_dataset_clean.csv')

df.sample(5)
# Out:
#      product_id             annotated_image_name fabric_types_clean  \
# 51           11  0560000069371_2.jpg___dress.png             Cotton
# 736        1627              0540000023673_2.jpg               Silk
# 186        8000              0460000028987_2.jpg              Linen
# 484        3116                0410000105598.jpg       Cotton Blend
# 428         861                0560000070030.jpg             Cotton
#
#     wear_types_clean        colors_clean        textures_clean  \
# 51             Saree                 red  Screen Print,Printed
# 736            Saree      brown,red,pink   applique,embroidery
# 186        Nightwear              yellow    embroidery,printed
# 484        Maternity   black,purple,blue            embroidery
# 428            Saree  golden,purple,pink                 opera
#
#     value_additions_clean
# 51           Screen Print
# 736              applique
# 186                   NaN
# 484                   NaN
# 428                   NaN

# %% [markdown]
# Try MLB for textures

# %%
from sklearn.preprocessing import MultiLabelBinarizer

def ml_binarizer(df, column_name):
	"""
	Function to transform a column of lists into one-hot encoded columns.
	"""
	mlb = MultiLabelBinarizer()

	temp_col = column_name + '_as_list'
	df[temp_col] = df[column_name].apply(lambda x: x.split(',') if isinstance(x, str) else [])

	one_hot = mlb.fit_transform(df[temp_col])

	one_hot_cols = [f"{column_name}__{c}" for c in mlb.classes_]

	one_hot_df = pd.DataFrame(one_hot, columns=one_hot_cols, index=df.index)

	return pd.concat([df, one_hot_df], axis=1).drop(columns=[temp_col])

# %%
df = ml_binarizer(df, 'textures_clean')

df.sample(5)
# Out:
#      product_id             annotated_image_name fabric_types_clean  \
# 646        2134  0550000147859_1.jpg___dress.png             Muslin
# 383        2927   0430000116817_3.jpg___full.png               Silk
# 70           13              0560000069851_2.jpg             Cotton
# 64            2  0560000073100_2.jpg___dress.png             Cotton
# 718        1737              0550000149616_2.jpg               Silk
#
#     wear_types_clean                 colors_clean              textures_clean  \
# 646            Saree  grey,purple,blue,black,cyan   embroidery,nakshi,printed
# 383   Shalwar Kameez           yellow,white,green  embroidery,printed,striped
# 70             Saree             orange,pink,blue          embroidery,printed
# 64             Saree               grey,white,red                screen print
# 718            Saree                 golden,green                       opera
#
#     value_additions_clean  textures_clean__Block Print  \
# 646                nakshi                            0
# 383                   NaN                            0
# 70                    NaN                            0
# 64                    NaN                            0
# 718                   NaN                            0
#
#      textures_clean__Floral  textures_clean__Hand Embroidery  ...  \
# 646                       0                                0  ...
# 383                       0                                0  ...
# 70                        0                                0  ...
# 64                        0                                0  ...
# 718                       0                                0  ...
#
#      textures_clean__hand paint  textures_clean__mauve  \
# 646                           0                      0
# 383                           0                      0
# 70                            0                      0
# 64                            0                      0
# 718                           0                      0
#
#      textures_clean__nakshi  textures_clean__opera  textures_clean__printed  \
# 646                       1                      0                        1
# 383                       0                      0                        1
# 70                        0                      0                        1
# 64                        0                      0                        0
# 718                       0                      1                        0
#
#      textures_clean__screen print  textures_clean__striped  \
# 646                             0                        0
# 383                             0                        1
# 70                              0                        0
# 64                              1                        0
# 718                             0                        0
#
#      textures_clean__textured  textures_clean__tie dye  \
# 646                         0                        0
# 383                         0                        0
# 70                          0                        0
# 64                          0                        0
# 718                         0                        0
#
#      textures_clean__wax dye
# 646                        0
# 383                        0
# 70                         0
# 64                         0
# 718                        0
#
# [5 rows x 34 columns]

# %% [markdown]
# Let's try one hot instead of mlb to single label feature columns.

# %%
from sklearn.preprocessing import OneHotEncoder

def onehot_encode(df, column_name):
	"""
	Generate onehot encoded columns for given column
	"""
	ohe = OneHotEncoder(sparse_output=False, drop='first')
	
	one_hot = ohe.fit_transform(df[[column_name]])
	
	#oh_columns = [f"{column_name}__{oh_category}" for oh_category in ohe.categories_[0]]
	oh_columns = [f"{column_name}__{oh_category}" for oh_category in ohe.categories_[0][1:]]
	one_hot_df = pd.DataFrame(one_hot, columns=oh_columns, index=df.index)

	return pd.concat([df, one_hot_df], axis=1)

# %%
df = onehot_encode(df, 'fabric_types_clean')

df.sample(5)
# Out:
#      product_id             annotated_image_name fabric_types_clean  \
# 637        6619                0570000128211.jpg            Viscose
# 786        1985                0540000024800.jpg               Silk
# 75           14  0560000072297_2.jpg___dress.png             Cotton
# 739        1165                0560000067816.jpg             Cotton
# 183        6888     0570000125697.jpg___full.png            Viscose
#
#     wear_types_clean       colors_clean        textures_clean  \
# 637          Panjabi   pink,purple,blue           block print
# 786            Saree  brown,golden,pink                   NaN
# 75             Saree          grey,blue  tie dye,screen print
# 739            Saree  golden,green,blue           block print
# 183          Panjabi  brown,yellow,grey           block print
#
#     value_additions_clean  textures_clean__Block Print  \
# 637                   NaN                            0
# 786                   NaN                            0
# 75                    NaN                            0
# 739                   NaN                            0
# 183                   NaN                            0
#
#      textures_clean__Floral  textures_clean__Hand Embroidery  ...  \
# 637                       0                                0  ...
# 786                       0                                0  ...
# 75                        0                                0  ...
# 739                       0                                0  ...
# 183                       0                                0  ...
#
#      fabric_types_clean__Linen  fabric_types_clean__Muslin  \
# 637                        0.0                         0.0
# 786                        0.0                         0.0
# 75                         0.0                         0.0
# 739                        0.0                         0.0
# 183                        0.0                         0.0
#
#      fabric_types_clean__Muslin Blend  fabric_types_clean__Poplin  \
# 637                               0.0                         0.0
# 786                               0.0                         0.0
# 75                                0.0                         0.0
# 739                               0.0                         0.0
# 183                               0.0                         0.0
#
#      fabric_types_clean__Silk  fabric_types_clean__Silk Blend  \
# 637                       0.0                             0.0
# 786                       1.0                             0.0
# 75                        0.0                             0.0
# 739                       0.0                             0.0
# 183                       0.0                             0.0
#
#      fabric_types_clean__Synthetic  fabric_types_clean__Viscose  \
# 637                            0.0                          1.0
# 786                            0.0                          0.0
# 75                             0.0                          0.0
# 739                            0.0                          0.0
# 183                            0.0                          1.0
#
#      fabric_types_clean__Viscose Blend  fabric_types_clean__Voile
# 637                                0.0                        0.0
# 786                                0.0                        0.0
# 75                                 0.0                        0.0
# 739                                0.0                        0.0
# 183                                0.0                        0.0
#
# [5 rows x 46 columns]

# %%
from my_utils.dataset_utils import get_multilabel_counts
